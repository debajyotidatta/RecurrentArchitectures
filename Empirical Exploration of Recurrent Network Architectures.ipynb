# %% [markdown]
# This article will explore a huge variety of recurrent neural network architectures. This article is mainly motivated by this paper "An Empirical Exploration of Recurrent Network Architectures" and we will implement the network architecures that were highlighted in the paper.
#
# The implementation will be using Google's Tensorflow and we will implement the code on top of the Recurrent Neural Network example in the tensorflow website and on top of the code written by Jim Flemming in this blog article here: https://github.com/fomorians/lstm-odyssey. I have updated the code based on the new tensorflow version (0.12 as of today) and the recurrent neural network architectures are based on the paper "An Empirical Exploration of Recurrent Network Architectures" http://jmlr.org/proceedings/papers/v37/jozefowicz15.pdf.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
import time
import numpy as np
import pandas as pd
import tensorflow as tf


rnn_cell = tf.nn.rnn_cell

sequence_loss_by_example = tf.nn.seq2seq.sequence_loss_by_example
# parses the dataset
import ptb_reader

# import variants
from variants.vanilla import VanillaLSTMCell
from variants.vanillaRNN import VanillaRNNCell
# from variants.nig import NIGLSTMCell
# from variants.nfg import NFGLSTMCell
# from variants.nog import NOGLSTMCell
# from variants.niaf import NIAFLSTMCell
# from variants.noaf import NOAFLSTMCell
# from variants.np import NPLSTMCell
# from variants.cifg import CIFGLSTMCell
# from variants.fgr import FGRLSTMCell

# %%
data_path = '../../Machine175/AttentionModels/rnn/data/simple-examples/data/'
train_data, valid_data, test_data, _ = ptb_reader.ptb_raw_data(data_path)

# %%
# ??rnn_cell.BasicRNNCell

# %%
model_path = '.'
checkpoint_path = '.'
summary_path = '.'

# %%
def write_csv(arr, path):
    df = pd.DataFrame(arr)
    df.to_csv(path)

class PTBModel(object):
    def __init__(self, CellType, is_training, config):
        self.batch_size = batch_size = config.batch_size
        self.num_steps = num_steps = config.num_steps
        size = config.hidden_size
        vocab_size = config.vocab_size

        self.input_data = tf.placeholder(tf.int32, [batch_size, num_steps], name="input_data")
        self.targets = tf.placeholder(tf.int32, [batch_size, num_steps], name="targets")

        lstm_cell = CellType(size)
        if is_training and config.keep_prob < 1:
            lstm_cell = rnn_cell.DropoutWrapper(lstm_cell, output_keep_prob=config.keep_prob)
        cell = rnn_cell.MultiRNNCell([lstm_cell] * config.num_layers)
        self.initial_state = cell.zero_state(batch_size, tf.float32)

        # initializer used for reusable variable initializer (see `get_variable`)
        initializer = tf.random_uniform_initializer(-config.init_scale, config.init_scale)

        with tf.device("/cpu:0"):
            embedding = tf.get_variable("embedding", [vocab_size, size], initializer=initializer)
            inputs = tf.nn.embedding_lookup(embedding, self.input_data)

        if is_training and config.keep_prob < 1:
            inputs = tf.nn.dropout(inputs, config.keep_prob)

        outputs = []
        states = []
        state = self.initial_state

        with tf.variable_scope("RNN", initializer=initializer):
            for time_step in range(num_steps):
                if time_step > 0:
                    tf.get_variable_scope().reuse_variables()

                inputs_slice = inputs[:,time_step,:]
                (cell_output, state) = cell(inputs_slice, state)

                outputs.append(cell_output)
                states.append(state)

        self.final_state = states[-1]

        output = tf.reshape(tf.concat(1, outputs), [-1, size])
        w = tf.get_variable("softmax_w",
                                    [size, vocab_size],
                                    initializer=initializer)
        b = tf.get_variable("softmax_b", [vocab_size], initializer=initializer)

        logits = tf.nn.xw_plus_b(output, w, b) # compute logits for loss
        targets = tf.reshape(self.targets, [-1]) # reshape our target outputs
        weights = tf.ones([batch_size * num_steps]) # used to scale the loss average

        # computes loss and performs softmax on our fully-connected output layer
        loss = sequence_loss_by_example([logits], [targets], [weights], vocab_size)
        self.cost = cost = tf.div(tf.reduce_sum(loss), batch_size, name="cost")

        if is_training:
            # setup learning rate variable to decay
            self.lr = tf.Variable(1.0, trainable=False)

            # define training operation and clip the gradients
            tvars = tf.trainable_variables()
            grads, _ = tf.clip_by_global_norm(tf.gradients(cost, tvars), config.max_grad_norm)
            optimizer = tf.train.GradientDescentOptimizer(self.lr)
            self.train_op = optimizer.apply_gradients(zip(grads, tvars), name="train")
        else:
            # if this model isn't for training (i.e. testing/validation) then we don't do anything here
            self.train_op = tf.no_op()

# %%
def run_epoch(sess, model, data, verbose=False):
    epoch_size = ((len(data) // model.batch_size) - 1) // model.num_steps
    start_time = time.time()

    # accumulated counts
    costs = 0.0
    iters = 0

    # initial RNN state
#     state = model.initial_state.eval()
    state = sess.run(model.initial_state)

    for step, (x, y) in enumerate(ptb_reader.ptb_iterator(data, model.batch_size, model.num_steps)):
        cost, state, _ = sess.run([model.cost, model.final_state, model.train_op], feed_dict={
            model.input_data: x,
            model.targets: y,
            model.initial_state: state
        })
        costs += cost
        iters += model.num_steps

        perplexity = np.exp(costs / iters)

        if verbose and step % 10 == 0:
            progress = (step / epoch_size) * 100
            wps = iters * model.batch_size / (time.time() - start_time)
            print("%.1f%% Perplexity: %.3f (Cost: %.3f) Speed: %.0f wps" % (progress, perplexity, cost, wps))

    return (costs / iters), perplexity

class Config(object):
    batch_size = 20
    num_steps = 35 # number of unrolled time steps
    hidden_size = 450 # number of blocks in an LSTM cell
    vocab_size = 10000
    max_grad_norm = 5 # maximum gradient for clipping
    init_scale = 0.05 # scale between -0.1 and 0.1 for all random initialization
    keep_prob = 0.5 # dropout probability
    num_layers = 2 # number of LSTM layers
    learning_rate = 1.0
    lr_decay = 0.8
    lr_decay_epoch_offset = 6 # don't decay until after the Nth epoch

# default settings for training
train_config = Config()

# our evaluation runs (validation and testing), use a batch size and time step of one
eval_config = Config()
eval_config.batch_size = 1
eval_config.num_steps = 1

# number of epochs to perform over the training data
num_epochs = 39

cell_types = {
    'vanilla': VanillaLSTMCell,
    'vanillaRNN': VanillaRNNCell
#     'nig': NIGLSTMCell,
#     'nfg': NFGLSTMCell,
#     'nog': NOGLSTMCell,
#     'niaf': NIAFLSTMCell,
#     'noaf': NOAFLSTMCell,
#     'np': NPLSTMCell,
#     'cifg': CIFGLSTMCell,
#     'fgr': FGRLSTMCell,
}

model_name = "vanillaRNN"
CellType = cell_types[model_name]

with tf.Graph().as_default(), tf.Session() as sess:
    # define our training model
    with tf.variable_scope("model", reuse=None):
        train_model = PTBModel(CellType, is_training=True, config=train_config)

    # we create a separate model for validation and testing to alter the batch size and time steps
    # reuse=True reuses variables from the previously defined `train_model`
    with tf.variable_scope("model", reuse=True):
        valid_model = PTBModel(CellType, is_training=False, config=train_config)
        test_model = PTBModel(CellType, is_training=False, config=eval_config)

    # create a saver instance to restore from the checkpoint
    saver = tf.train.Saver(max_to_keep=1)

    # initialize our variables
    sess.run(tf.global_variables_initializer())

    # save the graph definition as a protobuf file
    tf.train.write_graph(sess.graph_def, model_path, '%s.pb'.format(model_name), as_text=False)

    train_costs = []
    train_perps = []
    valid_costs = []
    valid_perps = []

    for i in range(num_epochs):
        print("Epoch: %d Learning Rate: %.3f" % (i + 1, sess.run(train_model.lr)))

        # run training pass
        train_cost, train_perp = run_epoch(sess, train_model, train_data, verbose=True)
        print("Epoch: %i Training Perplexity: %.3f (Cost: %.3f)" % (i + 1, train_perp, train_cost))
        train_costs.append(train_cost)
        train_perps.append(train_perp)

        # run validation pass
        valid_cost, valid_perp = run_epoch(sess, valid_model, valid_data)
        print("Epoch: %i Validation Perplexity: %.3f (Cost: %.3f)" % (i + 1, valid_perp, valid_cost))
        valid_costs.append(valid_cost)
        valid_perps.append(valid_perp)

        saver.save(sess, checkpoint_path + 'checkpoint')

    # run test pass
    test_cost, test_perp = run_epoch(sess, test_model, test_data)
    print("Test Perplexity: %.3f (Cost: %.3f)" % (test_perp, test_cost))

    write_csv(train_costs, os.path.join(summary_path, "train_costs.csv"))
    write_csv(train_perps, os.path.join(summary_path, "train_perps.csv"))
    write_csv(valid_costs, os.path.join(summary_path, "valid_costs.csv"))
    write_csv(valid_perps, os.path.join(summary_path, "valid_perps.csv"))
# Out:
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_1/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_1/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_2/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_2/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_3/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_3/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_4/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_4/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_5/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_5/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_6/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_6/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_7/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_7/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_8/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_8/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_9/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_9/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_10/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_10/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_11/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_11/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_12/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_12/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_13/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_13/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_14/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_14/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_15/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_15/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_16/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_16/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_17/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_17/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_18/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_18/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_19/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_19/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_20/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_20/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_21/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_21/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_22/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_22/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_23/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_23/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_24/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_24/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_25/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_25/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_26/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_26/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_27/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_27/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_28/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_28/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_29/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_29/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_30/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_30/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_31/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_31/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_32/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_32/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_33/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_33/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_34/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model/RNN/MultiRNNCell_34/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_1/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_1/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_2/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_2/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_3/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_3/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_4/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_4/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_5/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_5/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_6/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_6/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_7/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_7/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_8/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_8/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_9/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_9/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_10/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_10/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_11/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_11/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_12/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_12/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_13/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_13/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_14/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_14/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_15/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_15/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_16/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_16/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_17/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_17/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_18/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_18/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_19/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_19/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_20/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_20/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_21/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_21/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_22/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_22/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_23/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_23/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_24/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_24/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_25/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_25/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ...
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_27/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_27/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_28/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_28/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_29/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_29/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_30/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_30/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_31/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_31/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_32/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_32/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_33/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_33/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_34/Cell0/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(20), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(20), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(20), Dimension(450)]), TensorShape([Dimension(20), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN/MultiRNNCell_34/Cell1/VanillaRNNCell/concat:0' shape=(20, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(1), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(1), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(1), Dimension(450)]), TensorShape([Dimension(1), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN_1/MultiRNNCell/Cell0/VanillaRNNCell/concat:0' shape=(1, 900) dtype=float32>)
# ('y_prev shape is ', TensorShape([Dimension(1), Dimension(450)]))
# ('state shape is ', TensorShape([Dimension(1), Dimension(900)]))
# ('shape of y and s_t is ', TensorShape([Dimension(1), Dimension(450)]), TensorShape([Dimension(1), Dimension(450)]))
# ('shape of tf.concat(1, [y, y]) is ', <tf.Tensor 'model_1/RNN_1/MultiRNNCell/Cell1/VanillaRNNCell/concat:0' shape=(1, 900) dtype=float32>)
# Epoch: 1 Learning Rate: 1.000
# 0.0% Perplexity: 10878.735 (Cost: 325.310) Speed: 977 wps
# 0.8% Perplexity: 57956.576 (Cost: 307.348) Speed: 5203 wps
# 1.5% Perplexity: 17687.248 (Cost: 289.906) Speed: 6812 wps
# 2.3% Perplexity: 10818.132 (Cost: 290.933) Speed: 7666 wps
# 3.0% Perplexity: 8324.671 (Cost: 275.194) Speed: 8186 wps
# 3.8% Perplexity: 6491.493 (Cost: 277.627) Speed: 8537 wps
# 4.5% Perplexity: 5695.262 (Cost: 285.157) Speed: 8778 wps
# 5.3% Perplexity: 4880.935 (Cost: 257.899) Speed: 8966 wps
# 6.0% Perplexity: 4382.048 (Cost: 258.610) Speed: 9105 wps
# 6.8% Perplexity: 4026.759 (Cost: 263.799) Speed: 9223 wps
# 7.5% Perplexity: 3662.226 (Cost: 250.542) Speed: 9322 wps
# 8.3% Perplexity: 3421.308 (Cost: 261.229) Speed: 9408 wps
# 9.0% Perplexity: 3272.075 (Cost: 259.139) Speed: 9482 wps
# 9.8% Perplexity: 3071.904 (Cost: 256.518) Speed: 9542 wps
# 10.6% Perplexity: 2969.063 (Cost: 251.611) Speed: 9589 wps
# 11.3% Perplexity: 2832.827 (Cost: 241.011) Speed: 9631 wps
# 12.1% Perplexity: 2740.700 (Cost: 253.787) Speed: 9671 wps
# 12.8% Perplexity: 2708.256 (Cost: 283.810) Speed: 9703 wps
# 13.6% Perplexity: 2660.423 (Cost: 259.989) Speed: 9732 wps
# 14.3% Perplexity: 2623.715 (Cost: 254.469) Speed: 9757 wps
# 15.1% Perplexity: 2575.184 (Cost: 249.639) Speed: 9781 wps
# 15.8% Perplexity: 2543.805 (Cost: 318.437) Speed: 9802 wps
# 16.6% Perplexity: 2485.687 (Cost: 259.342) Speed: 9821 wps
# 17.3% Perplexity: 2441.363 (Cost: 251.269) Speed: 9838 wps
# 18.1% Perplexity: 2387.543 (Cost: 249.397) Speed: 9854 wps
# 18.8% Perplexity: 2347.947 (Cost: 257.057) Speed: 9869 wps
# 19.6% Perplexity: 2314.057 (Cost: 245.607) Speed: 9883 wps
# 20.3% Perplexity: 2292.793 (Cost: 264.676) Speed: 9895 wps
# 21.1% Perplexity: 2249.887 (Cost: 247.928) Speed: 9908 wps
# 21.9% Perplexity: 2228.942 (Cost: 262.078) Speed: 9921 wps
# 22.6% Perplexity: 2192.466 (Cost: 241.090) Speed: 9932 wps
# 23.4% Perplexity: 2178.197 (Cost: 259.387) Speed: 9941 wps
# 24.1% Perplexity: 2157.519 (Cost: 258.340) Speed: 9947 wps
# 24.9% Perplexity: 2137.566 (Cost: 264.677) Speed: 9955 wps
# 25.6% Perplexity: 2119.189 (Cost: 257.810) Speed: 9963 wps
# 26.4% Perplexity: 2111.407 (Cost: 255.692) Speed: 9971 wps
# 27.1% Perplexity: 2089.809 (Cost: 250.845) Speed: 9978 wps
# 27.9% Perplexity: 2075.756 (Cost: 298.241) Speed: 9985 wps
# 28.6% Perplexity: 2058.435 (Cost: 246.899) Speed: 9991 wps
# 29.4% Perplexity: 2036.509 (Cost: 246.821) Speed: 9997 wps
# 30.1% Perplexity: 2024.273 (Cost: 254.578) Speed: 10001 wps
# 30.9% Perplexity: 2007.249 (Cost: 247.775) Speed: 10008 wps
# 31.7% Perplexity: 1994.261 (Cost: 256.248) Speed: 10012 wps
# 32.4% Perplexity: 1983.237 (Cost: 250.917) Speed: 10017 wps
# 33.2% Perplexity: 1977.532 (Cost: 250.785) Speed: 10021 wps
# 33.9% Perplexity: 1970.755 (Cost: 250.646) Speed: 10026 wps
# 34.7% Perplexity: 1955.270 (Cost: 266.036) Speed: 10031 wps
# 35.4% Perplexity: 1947.223 (Cost: 258.828) Speed: 10036 wps
# 36.2% Perplexity: 1940.891 (Cost: 262.832) Speed: 10041 wps
# 36.9% Perplexity: 1930.065 (Cost: 256.329) Speed: 10044 wps
# 37.7% Perplexity: 1918.689 (Cost: 246.177) Speed: 10049 wps
# 38.4% Perplexity: 1913.785 (Cost: 245.803) Speed: 10052 wps
# 39.2% Perplexity: 1901.603 (Cost: 250.054) Speed: 10057 wps
# 39.9% Perplexity: 1890.141 (Cost: 253.063) Speed: 10059 wps
# 40.7% Perplexity: 1886.722 (Cost: 262.862) Speed: 10062 wps
# 41.4% Perplexity: 1882.479 (Cost: 257.345) Speed: 10066 wps
# 42.2% Perplexity: 1871.464 (Cost: 247.413) Speed: 10069 wps
# 43.0% Perplexity: 1865.541 (Cost: 270.087) Speed: 10071 wps
# 43.7% Perplexity: 1857.925 (Cost: 284.373) Speed: 10074 wps
# 44.5% Perplexity: 1855.386 (Cost: 264.399) Speed: 10077 wps
# 45.2% Perplexity: 1848.521 (Cost: 247.460) Speed: 10080 wps
# 46.0% Perplexity: 1850.535 (Cost: 264.592) Speed: 10082 wps
# 46.7% Perplexity: 1847.070 (Cost: 282.380) Speed: 10085 wps
# 47.5% Perplexity: 1842.290 (Cost: 263.474) Speed: 10088 wps
# 48.2% Perplexity: 1836.437 (Cost: 277.041) Speed: 10090 wps
# 49.0% Perplexity: 1830.184 (Cost: 266.060) Speed: 10092 wps
# 49.7% Perplexity: 1828.354 (Cost: 324.099) Speed: 10094 wps
# 50.5% Perplexity: 1821.273 (Cost: 253.905) Speed: 10096 wps
# 51.2% Perplexity: 1820.864 (Cost: 254.191) Speed: 10099 wps
# 52.0% Perplexity: 1814.907 (Cost: 260.538) Speed: 10101 wps
# 52.8% Perplexity: 1811.508 (Cost: 251.782) Speed: 10102 wps
# 53.5% Perplexity: 1809.345 (Cost: 255.856) Speed: 10104 wps
# 54.3% Perplexity: 1803.630 (Cost: 246.056) Speed: 10105 wps
# 55.0% Perplexity: 1797.455 (Cost: 285.428) Speed: 10107 wps
# 55.8% Perplexity: 1791.410 (Cost: 241.813) Speed: 10109 wps
# 56.5% Perplexity: 1788.014 (Cost: 252.825) Speed: 10111 wps
# 57.3% Perplexity: 1787.219 (Cost: 267.265) Speed: 10113 wps
# 58.0% Perplexity: 1783.447 (Cost: 248.769) Speed: 10116 wps
# 58.8% Perplexity: 1780.319 (Cost: 247.180) Speed: 10119 wps
# 59.5% Perplexity: 1778.386 (Cost: 250.264) Speed: 10123 wps
# 60.3% Perplexity: 1772.072 (Cost: 257.355) Speed: 10125 wps
# 61.0% Perplexity: 1769.569 (Cost: 291.988) Speed: 10128 wps
# 61.8% Perplexity: 1767.673 (Cost: 260.420) Speed: 10129 wps
# 62.5% Perplexity: 1764.234 (Cost: 255.539) Speed: 10131 wps
# 63.3% Perplexity: 1761.954 (Cost: 256.862) Speed: 10133 wps
# 64.1% Perplexity: 1755.202 (Cost: 254.657) Speed: 10134 wps
# 64.8% Perplexity: 1749.910 (Cost: 246.220) Speed: 10136 wps
# 65.6% Perplexity: 1749.260 (Cost: 245.499) Speed: 10139 wps
# 66.3% Perplexity: 1745.448 (Cost: 250.255) Speed: 10140 wps
# 67.1% Perplexity: 1745.912 (Cost: 250.931) Speed: 10142 wps
# 67.8% Perplexity: 1745.327 (Cost: 246.995) Speed: 10142 wps
# 68.6% Perplexity: 1741.602 (Cost: 259.662) Speed: 10143 wps
# 69.3% Perplexity: 1740.611 (Cost: 275.426) Speed: 10144 wps
# 70.1% Perplexity: 1737.461 (Cost: 262.314) Speed: 10145 wps
# 70.8% Perplexity: 1735.028 (Cost: 260.489) Speed: 10146 wps
# 71.6% Perplexity: 1732.751 (Cost: 267.255) Speed: 10146 wps
# 72.3% Perplexity: 1729.005 (Cost: 247.349) Speed: 10147 wps
# 73.1% Perplexity: 1726.277 (Cost: 245.105) Speed: 10148 wps
# 73.9% Perplexity: 1722.799 (Cost: 254.286) Speed: 10148 wps
# 74.6% Perplexity: 1719.248 (Cost: 261.741) Speed: 10149 wps
# 75.4% Perplexity: 1715.577 (Cost: 258.810) Speed: 10151 wps
# 76.1% Perplexity: 1713.814 (Cost: 250.980) Speed: 10154 wps
# 76.9% Perplexity: 1712.727 (Cost: 248.206) Speed: 10156 wps
# 77.6% Perplexity: 1712.731 (Cost: 300.177) Speed: 10157 wps
# 78.4% Perplexity: 1711.015 (Cost: 237.871) Speed: 10158 wps
# 79.1% Perplexity: 1707.471 (Cost: 250.747) Speed: 10159 wps
# 79.9% Perplexity: 1702.633 (Cost: 233.635) Speed: 10160 wps
# 80.6% Perplexity: 1697.495 (Cost: 243.138) Speed: 10161 wps
# 81.4% Perplexity: 1692.533 (Cost: 246.393) Speed: 10162 wps
# 82.1% Perplexity: 1684.971 (Cost: 252.658) Speed: 10163 wps
# 82.9% Perplexity: 1677.742 (Cost: 245.146) Speed: 10164 wps
# 83.6% Perplexity: 1670.652 (Cost: 240.156) Speed: 10164 wps
# 84.4% Perplexity: 1664.548 (Cost: 236.133) Speed: 10164 wps
# 85.2% Perplexity: 1657.535 (Cost: 239.504) Speed: 10164 wps
# 85.9% Perplexity: 1650.257 (Cost: 247.829) Speed: 10165 wps
# 86.7% Perplexity: 1641.844 (Cost: 229.525) Speed: 10166 wps
# 87.4% Perplexity: 1634.632 (Cost: 230.280) Speed: 10166 wps
# 88.2% Perplexity: 1624.824 (Cost: 240.963) Speed: 10167 wps
# 88.9% Perplexity: 1617.122 (Cost: 235.314) Speed: 10167 wps
# 89.7% Perplexity: 1607.947 (Cost: 235.766) Speed: 10168 wps
# 90.4% Perplexity: 1598.436 (Cost: 236.533) Speed: 10169 wps
# 91.2% Perplexity: 1589.088 (Cost: 235.323) Speed: 10170 wps
# 91.9% Perplexity: 1580.020 (Cost: 245.129) Speed: 10170 wps
# 92.7% Perplexity: 1572.153 (Cost: 235.225) Speed: 10171 wps
# 93.4% Perplexity: 1567.116 (Cost: 244.148) Speed: 10171 wps
# 94.2% Perplexity: 1558.287 (Cost: 234.460) Speed: 10172 wps
# 95.0% Perplexity: 1549.309 (Cost: 228.344) Speed: 10172 wps
# 95.7% Perplexity: 1541.662 (Cost: 235.846) Speed: 10172 wps
# 96.5% Perplexity: 1535.189 (Cost: 237.819) Speed: 10173 wps
# 97.2% Perplexity: 1528.832 (Cost: 243.563) Speed: 10174 wps
# 98.0% Perplexity: 1523.722 (Cost: 240.885) Speed: 10175 wps
# 98.7% Perplexity: 1517.111 (Cost: 238.079) Speed: 10175 wps
# 99.5% Perplexity: 1510.968 (Cost: 238.844) Speed: 10176 wps
# Epoch: 1 Training Perplexity: 1507.782 (Cost: 7.318)
# Epoch: 1 Validation Perplexity: 899.673 (Cost: 6.802)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-fbc10a2fccbe> in <module>()
#     109         valid_perps.append(valid_perp)
#     110
# --> 111         saver.save(sess, checkpoint_path + 'checkpoint')
#     112
#     113     # run test pass
#
# /home/ubuntu/tensorflow/local/lib/python2.7/site-packages/tensorflow/python/training/saver.pyc in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state)
#    1308         raise ValueError(
#    1309             "'latest_filename' collides with 'save_path': '%s' and '%s'" %
# -> 1310             (latest_filename, save_path))
#    1311
#    1312     if not gfile.IsDirectory(os.path.dirname(save_path)):
#
# ValueError: 'latest_filename' collides with 'save_path': 'checkpoint' and 'checkpoints/checkpoint'

# %%
it = enumerate(ptb_reader.ptb_iterator(train_data, batch_size=20, num_steps=35))

# %%
step, (x, y) = next(it)

# %%
step

# %%
print (x.shape, y.shape)

# %%
zip(x,y)[0]
